# %%
#imports
import os
from collections import Counter
import pickle

import numpy as np

import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import Input, Model, layers, losses, optimizers, callbacks
from tensorflow.keras.datasets import mnist

from matplotlib import pyplot as plt
# Out:
# 2022-10-27 18:20:10.071270: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-27 18:20:10.387054: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-27 18:20:10.387109: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-27 18:20:10.442449: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-27 18:20:11.589337: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-10-27 18:20:11.589504: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-10-27 18:20:11.589521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
#load data
(xtrain_, ytrain), (xtest, ytest) = mnist.load_data()

# preprocessing: rescaling, reshaping
def preprocess_images(x):
    return x.astype('float32')/255.

xtrain = preprocess_images(xtrain_)

# Split some data for training/validation/testing
Xtrain_, Xrest_, Ytrain, Yrest_ = train_test_split(xtrain, ytrain, train_size=10000)
Xval_, Xrest_, Yval, Yrest_ = train_test_split(Xrest_, Yrest_, train_size=1000)
Xtest_, Xrest_, Ytest, Yrest_ = train_test_split(Xrest_, Yrest_, train_size=10000)

# plot some samples
idxs = np.random.choice(len(Xtrain_), 25, replace=False)
fig, axs = plt.subplots(5,5,figsize=(25,25))
for idx, ax in zip(idxs, axs.flatten()):
    ax.imshow(Xtrain_[idx])

#sklearn needs the format n_samples x n_feature
Xtrain = Xtrain_.reshape((Xtrain_.shape[0], -1))
Xtest = Xtest_.reshape((Xtest_.shape[0], -1))
print(Xtrain.shape)
print(Counter(Ytrain))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# (10000, 784)
# Counter({1: 1140, 7: 1062, 3: 1031, 9: 1002, 6: 999, 2: 982, 0: 970, 8: 949, 4: 949, 5: 916})

# %%
# train a classifier
LR = LogisticRegression(max_iter=1000)
LR.fit(Xtrain, Ytrain)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# evaluate trained classifier on test set
Ypred = LR.predict(Xtest)
print(classification_report(Ytest, Ypred))
print(confusion_matrix(Ytest, Ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      1032
#            1       0.94      0.96      0.95      1081
#            2       0.88      0.86      0.87       995
#            3       0.88      0.87      0.87       983
#            4       0.91      0.91      0.91       998
#            5       0.84      0.85      0.85       913
#            6       0.91      0.95      0.93       997
#            7       0.92      0.92      0.92      1056
#            8       0.88      0.82      0.85       948
#            9       0.87      0.87      0.87       997
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000
#
# [[ 986    0    8    2    1   12   10    4    5    4]
#  [   0 1043    8    4    3    2    1    4   14    2]
#  [  10   18  857   25   12    6   23   17   20    7]
#  [   5    7   23  854    1   48    3    7   14   21]
#  [   5    3   10    1  904    6   10   12    8   39]
#  [  11    9   11   28   11  775   25    4   30    9]
#  [   6    4   11    2    4   17  948    1    3    1]
#  [   1    5   15    6   11    1    3  974    7   33]
#  [   3   21   28   33    9   41   12    1  781   19]
#  [   7    2    5   19   35   13    2   34    8  872]]

# %%
# try a better model
RF = RandomForestClassifier()
RF.fit(Xtrain, Ytrain)
# Out:
# RandomForestClassifier()

# %%
# evaluate trained classifier on test set
Ypred2 = RF.predict(Xtest)
print(classification_report(Ytest, Ypred2))
print(confusion_matrix(Ytest, Ypred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      1032
#            1       0.97      0.98      0.98      1081
#            2       0.95      0.94      0.94       995
#            3       0.94      0.92      0.93       983
#            4       0.93      0.94      0.94       998
#            5       0.92      0.95      0.93       913
#            6       0.96      0.97      0.96       997
#            7       0.96      0.95      0.96      1056
#            8       0.94      0.91      0.92       948
#            9       0.92      0.92      0.92       997
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# [[1009    0    1    2    1    4    5    0    7    3]
#  [   0 1064    6    4    1    0    1    2    3    0]
#  [   6    4  936    5   13    1    7    6   11    6]
#  [   2    1    9  901    2   36    0   11   11   10]
#  [   2    1    1    0  939    2    8    4    6   35]
#  [   5    5    0   11    3  863   16    0    6    4]
#  [  11    4    3    0    3    9  964    0    3    0]
#  [   1    5   14    3   11    0    0 1005    6   11]
#  [   3    7   12   17    9   15    4    0  867   14]
#  [   6    2    5   14   24    7    1   16    7  915]]

# %%
# Hyperparameter tuning
param_grid = {
    'n_estimators' : [200, 500],
    'max_depth' : [None, 10, 50],
    'max_features' : ['sqrt', 'log2', .1]
}

RF_tuned = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=4, n_jobs=-1, verbose=4)
RF_tuned.fit(Xtrain, Ytrain)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# [CV 3/4] END max_depth=None, max_features=sqrt, n_estimators=200;, score=0.944 total time=  16.1s
# [CV 1/4] END max_depth=None, max_features=sqrt, n_estimators=500;, score=0.957 total time=  49.1s
# [CV 4/4] END max_depth=None, max_features=log2, n_estimators=200;, score=0.942 total time=   7.2s
# [CV 4/4] END max_depth=None, max_features=log2, n_estimators=500;, score=0.946 total time=  17.6s
# [CV 4/4] END max_depth=None, max_features=0.1, n_estimators=200;, score=0.941 total time=  49.7s
# [CV 4/4] END max_depth=None, max_features=0.1, n_estimators=500;, score=0.942 total time= 1.8min
# [CV 3/4] END max_depth=10, max_features=sqrt, n_estimators=200;, score=0.933 total time=  11.7s
# [CV 2/4] END max_depth=10, max_features=sqrt, n_estimators=500;, score=0.943 total time=  29.1s
# [CV 3/4] END max_depth=10, max_features=log2, n_estimators=200;, score=0.924 total time=   5.9s
# [CV 2/4] END max_depth=10, max_features=log2, n_estimators=500;, score=0.936 total time=  15.7s
# [CV 2/4] END max_depth=10, max_features=0.1, n_estimators=200;, score=0.943 total time=  29.7s
# [CV 2/4] END max_depth=10, max_features=0.1, n_estimators=500;, score=0.943 total time=972.4min
# [CV 3/4] END max_depth=50, max_features=sqrt, n_estimators=200;, score=0.944 total time=  25.0s
# [CV 3/4] END max_depth=50, max_features=sqrt, n_estimators=500;, score=0.945 total time=  31.9s
# [CV 3/4] END max_depth=50, max_features=log2, n_estimators=200;, score=0.942 total time=   5.5s
# [CV 3/4] END max_depth=50, max_features=log2, n_estimators=500;, score=0.942 total time=  13.7s
# [CV 3/4] END max_depth=50, max_features=0.1, n_estimators=200;, score=0.945 total time=  32.1s
# [CV 3/4] END max_depth=50, max_features=0.1, n_estimators=500;, score=0.946 total time= 1.2min
# [CV 1/4] END max_depth=None, max_features=sqrt, n_estimators=200;, score=0.950 total time=  16.3s
# [CV 2/4] END max_depth=None, max_features=sqrt, n_estimators=500;, score=0.949 total time=  48.4s
# [CV 1/4] END max_depth=None, max_features=log2, n_estimators=200;, score=0.955 total time=   7.1s
# [CV 1/4] END max_depth=None, max_features=log2, n_estimators=500;, score=0.955 total time=  17.5s
# [CV 3/4] END max_depth=None, max_features=0.1, n_estimators=200;, score=0.946 total time=  49.8s
# [CV 2/4] END max_depth=None, max_features=0.1, n_estimators=500;, score=0.952 total time= 1.8min
# [CV 4/4] END max_depth=10, max_features=sqrt, n_estimators=200;, score=0.932 total time=  12.0s
# [CV 4/4] END max_depth=10, max_features=sqrt, n_estimators=500;, score=0.933 total time=  29.4s
# [CV 4/4] END max_depth=10, max_features=log2, n_estimators=200;, score=0.932 total time=   7.4s
# [CV 4/4] END max_depth=10, max_features=log2, n_estimators=500;, score=0.931 total time=  14.9s
# [CV 4/4] END max_depth=10, max_features=0.1, n_estimators=200;, score=0.930 total time=  29.7s
# [CV 4/4] END max_depth=10, max_features=0.1, n_estimators=500;, score=0.934 total time=972.4min
# [CV 4/4] END max_depth=50, max_features=sqrt, n_estimators=200;, score=0.942 total time=  21.4s
# [CV 4/4] END max_depth=50, max_features=sqrt, n_estimators=500;, score=0.944 total time=  31.5s
# [CV 1/4] END max_depth=50, max_features=log2, n_estimators=500;, score=0.951 total time=  13.9s
# [CV 1/4] END max_depth=50, max_features=0.1, n_estimators=200;, score=0.948 total time=  29.3s
# [CV 1/4] END max_depth=50, max_features=0.1, n_estimators=500;, score=0.951 total time= 1.3min
# [CV 2/4] END max_depth=None, max_features=sqrt, n_estimators=200;, score=0.947 total time=  16.5s
# [CV 4/4] END max_depth=None, max_features=sqrt, n_estimators=500;, score=0.943 total time=  48.2s
# [CV 3/4] END max_depth=None, max_features=log2, n_estimators=200;, score=0.942 total time=   7.1s
# [CV 2/4] END max_depth=None, max_features=log2, n_estimators=500;, score=0.947 total time=  16.7s
# [CV 1/4] END max_depth=None, max_features=0.1, n_estimators=200;, score=0.949 total time=  50.7s
# [CV 3/4] END max_depth=None, max_features=0.1, n_estimators=500;, score=0.943 total time= 1.8min
# [CV 2/4] END max_depth=10, max_features=sqrt, n_estimators=200;, score=0.938 total time=  12.3s
# [CV 3/4] END max_depth=10, max_features=sqrt, n_estimators=500;, score=0.934 total time=  28.7s
# [CV 2/4] END max_depth=10, max_features=log2, n_estimators=200;, score=0.935 total time=   6.4s
# [CV 3/4] END max_depth=10, max_features=log2, n_estimators=500;, score=0.930 total time=  15.8s
# [CV 3/4] END max_depth=10, max_features=0.1, n_estimators=200;, score=0.936 total time=  29.9s
# [CV 3/4] END max_depth=10, max_features=0.1, n_estimators=500;, score=0.934 total time=972.3min
# [CV 2/4] END max_depth=50, max_features=sqrt, n_estimators=200;, score=0.950 total time=  26.8s
# [CV 2/4] END max_depth=50, max_features=sqrt, n_estimators=500;, score=0.949 total time=  31.3s
# [CV 2/4] END max_depth=50, max_features=log2, n_estimators=200;, score=0.947 total time=   5.4s
# [CV 2/4] END max_depth=50, max_features=log2, n_estimators=500;, score=0.946 total time=  13.5s
# [CV 2/4] END max_depth=50, max_features=0.1, n_estimators=200;, score=0.950 total time=  30.8s
# [CV 2/4] END max_depth=50, max_features=0.1, n_estimators=500;, score=0.950 total time= 1.2min
# [CV 4/4] END max_depth=None, max_features=sqrt, n_estimators=200;, score=0.943 total time=  16.3s
# [CV 3/4] END max_depth=None, max_features=sqrt, n_estimators=500;, score=0.945 total time=  48.3s
# [CV 2/4] END max_depth=None, max_features=log2, n_estimators=200;, score=0.944 total time=   7.8s
# [CV 3/4] END max_depth=None, max_features=log2, n_estimators=500;, score=0.944 total time=  16.4s
# [CV 2/4] END max_depth=None, max_features=0.1, n_estimators=200;, score=0.954 total time=  50.0s
# [CV 1/4] END max_depth=None, max_features=0.1, n_estimators=500;, score=0.952 total time= 1.7min
# [CV 1/4] END max_depth=10, max_features=sqrt, n_estimators=200;, score=0.941 total time=  12.1s
# [CV 1/4] END max_depth=10, max_features=sqrt, n_estimators=500;, score=0.944 total time=  28.3s
# [CV 1/4] END max_depth=10, max_features=log2, n_estimators=200;, score=0.932 total time=   4.8s
# [CV 1/4] END max_depth=10, max_features=log2, n_estimators=500;, score=0.936 total time=  16.7s
# [CV 1/4] END max_depth=10, max_features=0.1, n_estimators=200;, score=0.942 total time=  29.8s
# [CV 1/4] END max_depth=10, max_features=0.1, n_estimators=500;, score=0.943 total time=972.2min
# [CV 1/4] END max_depth=50, max_features=sqrt, n_estimators=200;, score=0.950 total time=  31.9s
# [CV 1/4] END max_depth=50, max_features=sqrt, n_estimators=500;, score=0.956 total time=  32.4s
# [CV 1/4] END max_depth=50, max_features=log2, n_estimators=200;, score=0.949 total time=   5.1s
# [CV 4/4] END max_depth=50, max_features=log2, n_estimators=200;, score=0.943 total time=   5.6s
# [CV 4/4] END max_depth=50, max_features=log2, n_estimators=500;, score=0.945 total time=  13.5s
# [CV 4/4] END max_depth=50, max_features=0.1, n_estimators=200;, score=0.940 total time=  33.1s
# [CV 4/4] END max_depth=50, max_features=0.1, n_estimators=500;, score=0.940 total time= 1.2min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 9
#       2 param_grid = {
#       3     'n_estimators' : [200, 500],
#       4     'max_depth' : [None, 10, 50],
#       5     'max_features' : ['sqrt', 'log2', .1]
#       6 }
#       8 RF_tuned = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=4, n_jobs=-1, verbose=4)
# ----> 9 RF_tuned.fit(Xtrain, Ytrain)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:910, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     908 refit_start_time = time.time()
#     909 if y is not None:
# --> 910     self.best_estimator_.fit(X, y, **fit_params)
#     911 else:
#     912     self.best_estimator_.fit(X, **fit_params)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:476, in BaseForest.fit(self, X, y, sample_weight)
#     465 trees = [
#     466     self._make_estimator(append=False, random_state=random_state)
#     467     for i in range(n_more_estimators)
#     468 ]
#     470 # Parallel loop: we prefer the threading backend as the Cython code
#     471 # for fitting the trees is internally releasing the Python GIL
#     472 # making threading more efficient than multiprocessing in
#     473 # that case. However, for joblib 0.12+ we respect any
#     474 # parallel_backend contexts set at a higher level,
#     475 # since correctness does not rely on using threads.
# --> 476 trees = Parallel(
#     477     n_jobs=self.n_jobs,
#     478     verbose=self.verbose,
#     479     prefer="threads",
#     480 )(
#     481     delayed(_parallel_build_trees)(
#     482         t,
#     483         self.bootstrap,
#     484         X,
#     485         y,
#     486         sample_weight,
#     487         i,
#     488         len(trees),
#     489         verbose=self.verbose,
#     490         class_weight=self.class_weight,
#     491         n_samples_bootstrap=n_samples_bootstrap,
#     492     )
#     493     for i, t in enumerate(trees)
#     494 )
#     496 # Collect newly grown trees
#     497 self.estimators_.extend(trees)
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/.local/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/.local/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190 else:
#     191     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File ~/.local/lib/python3.10/site-packages/sklearn/tree/_classes.py:458, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     447 else:
#     448     builder = BestFirstTreeBuilder(
#     449         splitter,
#     450         min_samples_split,
#    (...)
#     455         self.min_impurity_decrease,
#     456     )
# --> 458 builder.build(self.tree_, X, y, sample_weight)
#     460 if self.n_outputs_ == 1 and is_classifier(self):
#     461     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# display crossvalidation results
cv_results = pd.DataFrame(RF_tuned.cv_results_)
disp_cols = ['param_n_estimators','param_max_depth', 'param_max_features', 'mean_fit_time', 'mean_test_score']
mapper = dict(zip(disp_cols[:3], ['n_estimators', 'max_depth', 'max_features']))
renamed_df = cv_results[disp_cols].copy()
renamed_df.rename(columns=mapper, inplace=True)
print(renamed_df.sort_values('mean_test_score', ascending=False))
# Out:
#    n_estimators max_depth max_features  mean_fit_time  mean_test_score
# 1           500      None         sqrt      27.517305           0.9487
# 3           500      None         log2      12.653463           0.9487
# 13          500        50         sqrt      25.956195           0.9484
# 5           500      None          0.1      58.348672           0.9478
# 0           200      None         sqrt      11.306649           0.9476
# 12          200        50         sqrt      11.622646           0.9476
# 15          500        50         log2      12.460339           0.9475
# 2           200      None         log2       5.115498           0.9473
# 14          200        50         log2       5.334117           0.9470
# 4           200      None          0.1      25.707240           0.9468
# 17          500        50          0.1      39.129763           0.9466
# 16          200        50          0.1      20.714308           0.9461
# 7           500        10         sqrt      24.630440           0.9376
# 11          500        10          0.1      44.561406           0.9360
# 9           500        10         log2      10.895681           0.9357
# 10          200        10          0.1      23.294729           0.9354
# 6           200        10         sqrt      10.043179           0.9354
# 8           200        10         log2       4.193443           0.9302

# %%
# evaluate trained classifier on test set
print(RF_tuned.best_params_)
Ypred3 = RF_tuned.predict(Xtest)
print(classification_report(Ytest, Ypred3))
print(confusion_matrix(Ytest, Ypred3))
# Out:
# {'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       988
#            1       0.97      0.98      0.98      1087
#            2       0.93      0.95      0.94      1006
#            3       0.95      0.92      0.93      1048
#            4       0.95      0.96      0.96       998
#            5       0.95      0.93      0.94       907
#            6       0.95      0.97      0.96       993
#            7       0.96      0.95      0.96      1081
#            8       0.94      0.92      0.93       935
#            9       0.93      0.92      0.93       957
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# [[ 961    1    2    0    1    2   10    0   10    1]
#  [   1 1070    7    3    2    2    1    0    1    0]
#  [  11    1  959    4    6    0    6   13    6    0]
#  [   5    4   24  964    2   18    4    9   10    8]
#  [   3    1    2    0  963    1    2    4    2   20]
#  [   8    6    4   15    4  844   13    0    7    6]
#  [   3    4    3    0    4    9  967    0    3    0]
#  [   1    6   13    3   12    0    0 1025    5   16]
#  [   2    8   11    9    8    9   11    3  861   13]
#  [   8    1    5   19   16    1    1   11   12  883]]

# %%
#Convolutional Neural Network in tensorflow using keras API

def mnist_clf(input_shape=(28,28,1), n_classes=10):
    inx = Input(input_shape)
    x = layers.Conv2D(32, kernel_size=(3, 3), strides=2, padding='same', activation='relu')(inx)
    x = layers.Conv2D(64, kernel_size=(3, 3), strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2D(128, kernel_size=(3, 3), strides=2, padding='same', activation='relu')(x)
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(n_classes)(x)
    return Model(inx, x)

clf_mnist = mnist_clf()
clf_mnist.summary()

# select loss function and optimizer
loss = losses.CategoricalCrossentropy(from_logits=True)
opt = optimizers.Nadam(learning_rate=1e-2)
clf_mnist.compile(loss=loss, optimizer=opt, metrics=['accuracy'])

# preprocess data: scaling of images, one-hot encoding of labels
def preprocess_tf(x, y):
    return x, tf.one_hot(y, depth=10, axis=-1)

trainset = tf.data.Dataset.from_tensor_slices((Xtrain_, Ytrain)).shuffle(Xtrain_.shape[0]).batch(256).map(preprocess_tf)
valset = tf.data.Dataset.from_tensor_slices((Xval_, Yval)).batch(1000).map(preprocess_tf)

# callback for saving model
MdlCpt = callbacks.ModelCheckpoint('cpt/convnet_mnist', save_best_only=True)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 32)        320
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 356,234
# Trainable params: 356,234
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = clf_mnist.fit(trainset, validation_data=valset, epochs=100, callbacks=[MdlCpt])
# Out:
# Epoch 1/100
# 40/40 [==============================] - 1s 11ms/step - loss: 0.8377 - accuracy: 0.7460 - val_loss: 0.3241 - val_accuracy: 0.9080
# INFO:tensorflow:Assets written to: cpt/convnet_mnist/assets
# Epoch 2/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1519 - accuracy: 0.9546 - val_loss: 0.2033 - val_accuracy: 0.9500
# INFO:tensorflow:Assets written to: cpt/convnet_mnist/assets
# Epoch 3/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0833 - accuracy: 0.9757 - val_loss: 0.1657 - val_accuracy: 0.9610
# INFO:tensorflow:Assets written to: cpt/convnet_mnist/assets
# Epoch 4/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0527 - accuracy: 0.9855 - val_loss: 0.1623 - val_accuracy: 0.9600
# INFO:tensorflow:Assets written to: cpt/convnet_mnist/assets
# Epoch 5/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0508 - accuracy: 0.9830 - val_loss: 0.1391 - val_accuracy: 0.9720
# INFO:tensorflow:Assets written to: cpt/convnet_mnist/assets
# Epoch 6/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0419 - accuracy: 0.9880 - val_loss: 0.2690 - val_accuracy: 0.9320
# Epoch 7/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0329 - accuracy: 0.9904 - val_loss: 0.1422 - val_accuracy: 0.9660
# Epoch 8/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.1838 - val_accuracy: 0.9670
# Epoch 9/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 0.1711 - val_accuracy: 0.9720
# Epoch 10/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.1357 - val_accuracy: 0.9730
# INFO:tensorflow:Assets written to: cpt/convnet_mnist/assets
# Epoch 11/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0993 - accuracy: 0.9729 - val_loss: 1.0670 - val_accuracy: 0.8470
# Epoch 12/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0922 - accuracy: 0.9743 - val_loss: 0.1571 - val_accuracy: 0.9670
# Epoch 13/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0179 - accuracy: 0.9945 - val_loss: 0.1453 - val_accuracy: 0.9730
# Epoch 14/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.1633 - val_accuracy: 0.9710
# Epoch 15/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1931 - val_accuracy: 0.9720
# Epoch 16/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.1590 - val_accuracy: 0.9790
# Epoch 17/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.1653 - val_accuracy: 0.9760
# Epoch 18/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.2410 - val_accuracy: 0.9690
# Epoch 19/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0279 - accuracy: 0.9937 - val_loss: 0.2128 - val_accuracy: 0.9660
# Epoch 20/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0202 - accuracy: 0.9949 - val_loss: 0.2084 - val_accuracy: 0.9680
# Epoch 21/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0126 - accuracy: 0.9964 - val_loss: 0.2060 - val_accuracy: 0.9580
# Epoch 22/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.1652 - val_accuracy: 0.9700
# Epoch 23/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 0.2608 - val_accuracy: 0.9590
# Epoch 24/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0703 - accuracy: 0.9846 - val_loss: 0.3924 - val_accuracy: 0.9200
# Epoch 25/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0325 - accuracy: 0.9916 - val_loss: 0.2444 - val_accuracy: 0.9610
# Epoch 26/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.2393 - val_accuracy: 0.9670
# Epoch 27/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0116 - accuracy: 0.9971 - val_loss: 0.2881 - val_accuracy: 0.9690
# Epoch 28/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0129 - accuracy: 0.9973 - val_loss: 0.1886 - val_accuracy: 0.9700
# Epoch 29/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.2064 - val_accuracy: 0.9740
# Epoch 30/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.2463 - val_accuracy: 0.9710
# Epoch 31/100
# 40/40 [==============================] - 0s 10ms/step - loss: 8.7938e-04 - accuracy: 0.9996 - val_loss: 0.2631 - val_accuracy: 0.9730
# Epoch 32/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 2.4169 - val_accuracy: 0.8390
# Epoch 33/100
# 40/40 [==============================] - 0s 9ms/step - loss: 2.2971 - accuracy: 0.6741 - val_loss: 0.6295 - val_accuracy: 0.8310
# Epoch 34/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.1554 - accuracy: 0.9529 - val_loss: 0.2112 - val_accuracy: 0.9520
# Epoch 35/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0490 - accuracy: 0.9849 - val_loss: 0.2133 - val_accuracy: 0.9560
# Epoch 36/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0212 - accuracy: 0.9937 - val_loss: 0.2433 - val_accuracy: 0.9540
# Epoch 37/100
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0141 - accuracy: 0.9950 - val_loss: 0.2476 - val_accuracy: 0.9590
# Epoch 38/100
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.2553 - val_accuracy: 0.9660
# Epoch 39/100
# 40/40 [==============================] - 0s 10ms/step - loss: 7.2224e-04 - accuracy: 0.9999 - val_loss: 0.2619 - val_accuracy: 0.9670
# Epoch 40/100
# 40/40 [==============================] - 0s 9ms/step - loss: 6.3127e-04 - accuracy: 0.9999 - val_loss: 0.2706 - val_accuracy: 0.9650
# Epoch 41/100
# 40/40 [==============================] - 0s 10ms/step - loss: 3.3653e-04 - accuracy: 1.0000 - val_loss: 0.2814 - val_accuracy: 0.9660
# Epoch 42/100
# 40/40 [==============================] - 0s 9ms/step - loss: 1.5386e-04 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.9660
# Epoch 43/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1397e-04 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9650
# Epoch 44/100
# 40/40 [==============================] - 0s 9ms/step - loss: 9.3388e-05 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9650
# Epoch 45/100
# 40/40 [==============================] - 0s 10ms/step - loss: 7.9557e-05 - accuracy: 1.0000 - val_loss: 0.2951 - val_accuracy: 0.9650
# Epoch 46/100
# 40/40 [==============================] - 0s 9ms/step - loss: 6.9029e-05 - accuracy: 1.0000 - val_loss: 0.2979 - val_accuracy: 0.9650
# Epoch 47/100
# 40/40 [==============================] - 0s 9ms/step - loss: 6.1226e-05 - accuracy: 1.0000 - val_loss: 0.3003 - val_accuracy: 0.9650
# Epoch 48/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.4700e-05 - accuracy: 1.0000 - val_loss: 0.3021 - val_accuracy: 0.9650
# Epoch 49/100
# 40/40 [==============================] - 0s 10ms/step - loss: 4.9437e-05 - accuracy: 1.0000 - val_loss: 0.3059 - val_accuracy: 0.9650
# Epoch 50/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.5174e-05 - accuracy: 1.0000 - val_loss: 0.3091 - val_accuracy: 0.9650
# Epoch 51/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.0953e-05 - accuracy: 1.0000 - val_loss: 0.3104 - val_accuracy: 0.9650
# Epoch 52/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.7511e-05 - accuracy: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9650
# Epoch 53/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.4576e-05 - accuracy: 1.0000 - val_loss: 0.3136 - val_accuracy: 0.9650
# Epoch 54/100
# 40/40 [==============================] - 0s 9ms/step - loss: 3.2037e-05 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9650
# Epoch 55/100
# 40/40 [==============================] - 0s 10ms/step - loss: 2.9800e-05 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9650
# Epoch 56/100
# 40/40 [==============================] - 0s 9ms/step - loss: 2.7780e-05 - accuracy: 1.0000 - val_loss: 0.3185 - val_accuracy: 0.9650
# Epoch 57/100
# 40/40 [==============================] - 0s 10ms/step - loss: 2.5990e-05 - accuracy: 1.0000 - val_loss: 0.3200 - val_accuracy: 0.9650
# Epoch 58/100
# 40/40 [==============================] - 0s 9ms/step - loss: 2.4428e-05 - accuracy: 1.0000 - val_loss: 0.3216 - val_accuracy: 0.9650
# Epoch 59/100
# 40/40 [==============================] - 0s 10ms/step - loss: 2.2976e-05 - accuracy: 1.0000 - val_loss: 0.3225 - val_accuracy: 0.9650
# Epoch 60/100
# 40/40 [==============================] - 0s 10ms/step - loss: 2.1909e-05 - accuracy: 1.0000 - val_loss: 0.3241 - val_accuracy: 0.9650
# Epoch 61/100
# 40/40 [==============================] - 0s 10ms/step - loss: 2.0561e-05 - accuracy: 1.0000 - val_loss: 0.3258 - val_accuracy: 0.9650
# Epoch 62/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.9315e-05 - accuracy: 1.0000 - val_loss: 0.3275 - val_accuracy: 0.9650
# Epoch 63/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.8258e-05 - accuracy: 1.0000 - val_loss: 0.3290 - val_accuracy: 0.9650
# Epoch 64/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.7312e-05 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9650
# Epoch 65/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.6441e-05 - accuracy: 1.0000 - val_loss: 0.3322 - val_accuracy: 0.9650
# Epoch 66/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.5610e-05 - accuracy: 1.0000 - val_loss: 0.3334 - val_accuracy: 0.9650
# Epoch 67/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.4850e-05 - accuracy: 1.0000 - val_loss: 0.3348 - val_accuracy: 0.9650
# Epoch 68/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.4147e-05 - accuracy: 1.0000 - val_loss: 0.3359 - val_accuracy: 0.9650
# Epoch 69/100
# 40/40 [==============================] - 0s 9ms/step - loss: 1.3503e-05 - accuracy: 1.0000 - val_loss: 0.3371 - val_accuracy: 0.9650
# Epoch 70/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.2887e-05 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9650
# Epoch 71/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.2323e-05 - accuracy: 1.0000 - val_loss: 0.3393 - val_accuracy: 0.9650
# Epoch 72/100
# 40/40 [==============================] - 0s 9ms/step - loss: 1.1798e-05 - accuracy: 1.0000 - val_loss: 0.3404 - val_accuracy: 0.9650
# Epoch 73/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.1274e-05 - accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.9650
# Epoch 74/100
# 40/40 [==============================] - 0s 9ms/step - loss: 1.0810e-05 - accuracy: 1.0000 - val_loss: 0.3426 - val_accuracy: 0.9660
# Epoch 75/100
# 40/40 [==============================] - 0s 10ms/step - loss: 1.0366e-05 - accuracy: 1.0000 - val_loss: 0.3437 - val_accuracy: 0.9660
# Epoch 76/100
# 40/40 [==============================] - 0s 9ms/step - loss: 9.9524e-06 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.9660
# Epoch 77/100
# 40/40 [==============================] - 0s 10ms/step - loss: 9.5579e-06 - accuracy: 1.0000 - val_loss: 0.3457 - val_accuracy: 0.9660
# Epoch 78/100
# 40/40 [==============================] - 0s 9ms/step - loss: 9.1800e-06 - accuracy: 1.0000 - val_loss: 0.3465 - val_accuracy: 0.9660
# Epoch 79/100
# 40/40 [==============================] - 0s 10ms/step - loss: 8.8295e-06 - accuracy: 1.0000 - val_loss: 0.3476 - val_accuracy: 0.9660
# Epoch 80/100
# 40/40 [==============================] - 0s 9ms/step - loss: 8.4878e-06 - accuracy: 1.0000 - val_loss: 0.3485 - val_accuracy: 0.9660
# Epoch 81/100
# 40/40 [==============================] - 0s 10ms/step - loss: 8.1711e-06 - accuracy: 1.0000 - val_loss: 0.3495 - val_accuracy: 0.9660
# Epoch 82/100
# 40/40 [==============================] - 0s 9ms/step - loss: 7.8598e-06 - accuracy: 1.0000 - val_loss: 0.3503 - val_accuracy: 0.9660
# Epoch 83/100
# 40/40 [==============================] - 0s 10ms/step - loss: 7.5679e-06 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.9660
# Epoch 84/100
# 40/40 [==============================] - 0s 10ms/step - loss: 7.2866e-06 - accuracy: 1.0000 - val_loss: 0.3526 - val_accuracy: 0.9660
# Epoch 85/100
# 40/40 [==============================] - 0s 10ms/step - loss: 6.9709e-06 - accuracy: 1.0000 - val_loss: 0.3539 - val_accuracy: 0.9660
# Epoch 86/100
# 40/40 [==============================] - 0s 10ms/step - loss: 6.7161e-06 - accuracy: 1.0000 - val_loss: 0.3547 - val_accuracy: 0.9660
# Epoch 87/100
# 40/40 [==============================] - 0s 10ms/step - loss: 6.4797e-06 - accuracy: 1.0000 - val_loss: 0.3556 - val_accuracy: 0.9660
# Epoch 88/100
# 40/40 [==============================] - 0s 9ms/step - loss: 6.2558e-06 - accuracy: 1.0000 - val_loss: 0.3566 - val_accuracy: 0.9660
# Epoch 89/100
# 40/40 [==============================] - 0s 10ms/step - loss: 6.0275e-06 - accuracy: 1.0000 - val_loss: 0.3577 - val_accuracy: 0.9660
# Epoch 90/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.8214e-06 - accuracy: 1.0000 - val_loss: 0.3586 - val_accuracy: 0.9660
# Epoch 91/100
# 40/40 [==============================] - 0s 10ms/step - loss: 5.6257e-06 - accuracy: 1.0000 - val_loss: 0.3594 - val_accuracy: 0.9660
# Epoch 92/100
# 40/40 [==============================] - 0s 10ms/step - loss: 5.4395e-06 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.9660
# Epoch 93/100
# 40/40 [==============================] - 0s 10ms/step - loss: 5.2598e-06 - accuracy: 1.0000 - val_loss: 0.3611 - val_accuracy: 0.9660
# Epoch 94/100
# 40/40 [==============================] - 0s 9ms/step - loss: 5.0889e-06 - accuracy: 1.0000 - val_loss: 0.3620 - val_accuracy: 0.9660
# Epoch 95/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.9226e-06 - accuracy: 1.0000 - val_loss: 0.3628 - val_accuracy: 0.9660
# Epoch 96/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.7666e-06 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9660
# Epoch 97/100
# 40/40 [==============================] - 0s 10ms/step - loss: 4.6134e-06 - accuracy: 1.0000 - val_loss: 0.3645 - val_accuracy: 0.9660
# Epoch 98/100
# 40/40 [==============================] - 0s 9ms/step - loss: 4.4639e-06 - accuracy: 1.0000 - val_loss: 0.3653 - val_accuracy: 0.9660
# Epoch 99/100
# 40/40 [==============================] - 0s 10ms/step - loss: 4.3256e-06 - accuracy: 1.0000 - val_loss: 0.3659 - val_accuracy: 0.9660
# Epoch 100/100
# 40/40 [==============================] - 0s 10ms/step - loss: 4.1871e-06 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.9660

# %%
# plot training metrics
fig, ax =plt.subplots(1,2, figsize=(16,8))
ax[0].semilogy(hist.history['loss'], label='train loss')
ax[0].semilogy(hist.history['val_loss'], label='validation loss')
ax[1].plot(hist.history['accuracy'], label='train accuracy');
ax[1].plot(hist.history['val_accuracy'], label='validation accuracy');
ax[0].legend();
ax[1].legend();
ax[1].grid()
ax[0].grid()
fig.suptitle('Training progress')

print('Metrics on test set')
# display results with trained classifier (100 epochs)
Ypred4 = tf.argmax(clf_mnist(Xtest_), axis=-1)
print(classification_report(Ytest, Ypred4))
print(confusion_matrix(Ytest, Ypred4))
# Out:
# Metrics on test set
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       988
#            1       0.98      0.99      0.99      1087
#            2       0.97      0.97      0.97      1006
#            3       0.97      0.96      0.97      1048
#            4       0.96      0.97      0.97       998
#            5       0.98      0.95      0.96       907
#            6       0.97      0.98      0.97       993
#            7       0.98      0.97      0.98      1081
#            8       0.94      0.95      0.94       935
#            9       0.96      0.95      0.96       957
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
#
# [[ 968    1    4    0    0    0    7    0    6    2]
#  [   1 1073    2    0    6    0    1    1    3    0]
#  [   1    3  980    9    1    0    1    5    3    3]
#  [   3    0    7 1011    0    4    0    4   15    4]
#  [   1    3    1    1  973    0    4    1    2   12]
#  [   0    0    2    8    4  865   10    0   12    6]
#  [   6    2    0    1    2    4  973    0    5    0]
#  [   1    3    8    2    7    0    0 1050    5    5]
#  [   2    4    2    7    6    8   10    1  887    8]
#  [   6    1    1    7   12    5    0    5    7  913]]

# %%
clf_mnist.evaluate(Xtest_, tf.one_hot(Ytest, depth=10), verbose=1)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2422 - accuracy: 0.9693
# [0.2421618402004242, 0.9692999720573425]

# %%
# load best model from checkpoint
print('Best model found in epoch ', np.argmin(hist.history['val_loss'])+1)
clf2 = tf.keras.models.load_model('cpt/convnet_mnist')
Ypred5 = tf.argmax(clf2(Xtest_), axis=-1)
print(classification_report(Ytest, Ypred5))
print(confusion_matrix(Ytest, Ypred5))
# Out:
# Best model found in epoch  10
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       988
#            1       0.98      0.99      0.99      1087
#            2       0.98      0.98      0.98      1006
#            3       0.98      0.97      0.97      1048
#            4       0.99      0.98      0.98       998
#            5       0.97      0.97      0.97       907
#            6       0.98      0.97      0.98       993
#            7       0.98      0.98      0.98      1081
#            8       0.97      0.96      0.97       935
#            9       0.96      0.97      0.96       957
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000
#
# [[ 975    1    1    0    0    3    1    0    4    3]
#  [   1 1077    2    0    1    2    2    0    1    1]
#  [   4    2  987    2    1    0    0    4    4    2]
#  [   3    3    4 1020    0    9    0    2    3    4]
#  [   1    2    3    1  978    0    1    4    0    8]
#  [   1    2    1    4    0  880    7    1    5    6]
#  [  12    1    0    1    1    6  967    0    4    1]
#  [   0    5    5    4    1    0    0 1056    6    4]
#  [   4    4    4    3    2    5    5    1  899    8]
#  [   6    0    1   10    5    2    1    5    2  925]]
